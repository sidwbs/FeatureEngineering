# %% [markdown]
# # Seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Distributions
# - there are many ways to display the distributions of a feature.
#     - histogram (distplot)
#     - Kdeplot
#     - rugplot

# %% [markdown]
# ### Histogram
# - a histogram is a univariate plot which helps us to understand the distribution of a continuous numerical variable. It is used when we have quantitative data.
# - it breaks the range of the continuous variabled into intervals of equal length and then counts the number of observations in each interval.
# - the way data is distributed or spread out in a histogram is called the distribution.
# - One reason why we might use a histogram instead of a bar chart or a dot plot is that we have too many data points.
# - the tallest clusters of bars i.e. peaks, in a histogram represent the modes of the data.

# %%
df1 = pd.read_csv('/Users/siddhantraj/Desktop/Business Analytics/Python For Data Science/Week3/Practice_Content/Automobile.csv')

# %%
df1.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
df1.shape
# Out:
# (201, 26)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            201 non-null    int64
#  1   normalized_losses    201 non-null    int64
#  2   make                 201 non-null    object
#  3   fuel_type            201 non-null    object
#  4   aspiration           201 non-null    object
#  5   number_of_doors      201 non-null    object
#  6   body_style           201 non-null    object
#  7   drive_wheels         201 non-null    object
#  8   engine_location      201 non-null    object
#  9   wheel_base           201 non-null    float64
#  10  length               201 non-null    float64
#  11  width                201 non-null    float64
#  12  height               201 non-null    float64
#  13  curb_weight          201 non-null    int64
#  14  engine_type          201 non-null    object
# ...

# %%
df1.describe(include = 'all').T
# Out:
#                      count unique     top freq          mean          std  \
# symboling            201.0    NaN     NaN  NaN      0.840796     1.254802
# normalized_losses    201.0    NaN     NaN  NaN    125.189055    33.572966
# make                   201     22  toyota   32           NaN          NaN
# fuel_type              201      2     gas  181           NaN          NaN
# aspiration             201      2     std  165           NaN          NaN
# number_of_doors        201      2    four  114           NaN          NaN
# body_style             201      5   sedan   94           NaN          NaN
# drive_wheels           201      3     fwd  118           NaN          NaN
# engine_location        201      2   front  198           NaN          NaN
# wheel_base           201.0    NaN     NaN  NaN     98.797015     6.066366
# length               201.0    NaN     NaN  NaN    174.200995    12.322175
# width                201.0    NaN     NaN  NaN     65.889055     2.101471
# ...

# %%
sns.histplot(data = df1, x = 'price')
plt.show()

# %% [markdown]
# - Using parameters like color, bins, binwidth, kde, hue, edgecolor, linewidth, linestyle

# %%
plt.title('Histogram:Price')
plt.xlim(3000, 50000)
plt.ylim(0,70)
plt.xlabel('Price of cars')
plt.ylabel('Frequency')
sns.histplot(data = df1, x = 'price', color = 'orange')
plt.show()

# %% [markdown]
# We can specify number of intervals to create by setting the bins parameter

# %%
sns.histplot(data = df1, x ='price', bins = 5)
plt.show()

# %%
sns.histplot(data = df1, x = 'price', bins = 20)
plt.show()

# %% [markdown]
# If we want to specify the width of the intervals, we can use binwidth parameter.

# %%
sns.histplot(data = df1, x = 'price', binwidth = 20)
plt.show()

# %%
sns.histplot(data = df1, x = 'price', binwidth = 200)
plt.show()

# %% [markdown]
# To find the optimal number of bins we can use the following rule of thumb:
#  $$ binwidth =\frac{(2 * IQR)}{\sqrt[3]{n}} $$ where n = number of rows the dataset
#
# - Then, we obtain bins using the calculated bin-width. $$ bins =\frac{Range}{binwidth} $$

# %% [markdown]
# - In addition to the bars, we can also add a density estimate by setting the kde parameter to True
# - Kde visualises the distribution of data over a continuous interval.

# %%
sns.histplot(data = df1, x = 'price', kde = True)
plt.show()

# %%
sns.histplot(data = df1, x = 'curb_weight', kde = True)
plt.show()

# %% [markdown]
# - a histogram skewed to the right has a large number of occurences on the left side of the plot and a few on the right side of the plot
# - a histogram skewed to the left has a large number of occurences on the right side of the plot and a few on the left side of the plot

# %%
sns.histplot(data = df1, x = 'price', hue = 'body_style', kde = True)
plt.show()

# %%
df2 = pd.read_csv('/Users/siddhantraj/Desktop/Python/Python Udemy/Python-ML and Data Science/UNZIP_FOR_NOTEBOOKS_FINAL/05-Seaborn/dm_office_sales.csv')

# %%
df2.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   division            1000 non-null   object
#  1   level of education  1000 non-null   object
#  2   training level      1000 non-null   int64
#  3   work experience     1000 non-null   int64
#  4   salary              1000 non-null   int64
#  5   sales               1000 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 47.0+ KB

# %%
sns.displot(data = df2, x = 'salary', kde = True)
plt.show()

# %%
sns.displot(data = df2, x = 'salary')
plt.show()

# %%
sns.histplot(data = df2, x = 'salary')
plt.show()

# %%
sns.histplot(data = df2, x = 'salary', bins = 10)
plt.show()

# %%
sns.histplot(data = df2, x = 'salary', bins = 100)
plt.show()

# %%
sns.set(style = 'darkgrid')
sns.histplot(data = df2, x = 'salary', bins = 100)
plt.show()

# %% [markdown]
# seaborn plot can accept keyword arguments directly from the matplotlib code that seaborn uses. Not every seaborn plot can accept all matplotlib arguments, but the main styling parameter are available

# %%
sns.displot(data = df2, x = 'salary', bins = 20, kde = False, color = 'red', 
            edgecolor = 'black', lw = 4, ls = '--')
plt.show()

# %% [markdown]
# ### Kde Plot
# - the kde plot maps an estimate of a probability density function of a random variable. Kde is a fundemental data smoothing problem where inferences about the population are made based on a finite data sample

# %%
np.random.seed(42)
sample_ages = np.random.randint(0,100,200)

# %%
sample_ages
# Out:
# array([51, 92, 14, 71, 60, 20, 82, 86, 74, 74, 87, 99, 23,  2, 21, 52,  1,
#        87, 29, 37,  1, 63, 59, 20, 32, 75, 57, 21, 88, 48, 90, 58, 41, 91,
#        59, 79, 14, 61, 61, 46, 61, 50, 54, 63,  2, 50,  6, 20, 72, 38, 17,
#         3, 88, 59, 13,  8, 89, 52,  1, 83, 91, 59, 70, 43,  7, 46, 34, 77,
#        80, 35, 49,  3,  1,  5, 53,  3, 53, 92, 62, 17, 89, 43, 33, 73, 61,
#        99, 13, 94, 47, 14, 71, 77, 86, 61, 39, 84, 79, 81, 52, 23, 25, 88,
#        59, 40, 28, 14, 44, 64, 88, 70,  8, 87,  0,  7, 87, 62, 10, 80,  7,
#        34, 34, 32,  4, 40, 27,  6, 72, 71, 11, 33, 32, 47, 22, 61, 87, 36,
#        98, 43, 85, 90, 34, 64, 98, 46, 77,  2,  0,  4, 89, 13, 26,  8, 78,
#        14, 89, 41, 76, 50, 62, 95, 51, 95,  3, 93, 22, 14, 42, 28, 35, 12,
#        31, 70, 58, 85, 27, 65, 41, 44, 61, 56,  5, 27, 27, 43, 83, 29, 61,
#        74, 91, 88, 61, 96,  0, 26, 61, 76,  2, 69, 71, 26])

# %%
sample_ages = pd.DataFrame(sample_ages, columns = ['age'])

# %%
sample_ages.head()
# Out:
#    age
# 0   51
# 1   92
# 2   14
# 3   71
# 4   60

# %%
sns.kdeplot(data = sample_ages, x = 'age')
plt.show()

# %% [markdown]
# - Using parameters like clip, bw_adjust

# %%
sns.kdeplot(data = sample_ages, x= 'age', clip = [0,100])
plt.show()

# %%
sns.kdeplot(data = sample_ages, x = 'age', bw_adjust = 0.5)
plt.show()

# %%
x = np.random.normal(0,1 ,size = 20)

# %%
from scipy import stats

# %%
plt.figure(figsize = (8,4), dpi = 200)
bandwidth = x.std() * x.size ** (-0.001)
support = np.linspace(-5,5 ,100)
kernels = []

plt.figure(figsize = (12,6))

for x_i in x:
    kernel = stats.norm(x_i, bandwidth).pdf(support)
    kernels.append(kernel)
    plt.plot(support, kernel, color = 'lightblue')
sns.rugplot(x, color = 'darkblue', linewidth = 4)
plt.show()

# %% [markdown]
# ## Box Plots
# - it displays the distribution of continuous variables. It does these through quartiles. We can create a boxplot per category.
# - a boxplot, or a box and whisker plot, shows the distribution of numerical data and skewness through displaying the data quantiles
# - it is also called as a five-number summary plot, where the five-number summary includes the minimum value, first quartile, median, third quartile and the maximum value
# - IQR defines the width of the box. Median is the 50TH Percentile.
# - The whiskers are defined by 1.5*IQR
# - Outside these whiskers are the Outliers.

# %%
sns.boxplot(data = df1, x = 'curb_weight')
plt.show()

# %%
plt.title('Boxplot: Horsepower')
plt.xlim(30,300)
plt.xlabel('Horsepower')
sns.axes_style('whitegrid')
sns.boxplot(data = df1, x = 'horsepower', color = 'green')
plt.show()

# %% [markdown]
# - in the boxplot when the median is closer to the left of the box and the whisker is shorter on the left end of the box, we say that the distribution is positively skewed (right skewed)
# - Similarly, when the median is closer to the right of the box and the whisker is shorter on the right end of the box, we say that the distribution is negatively skewed (left skewed)

# %%
sns.boxplot(data = df1, x = 'price')
plt.show()

# %% [markdown]
# - from the above plot we can say that the distribution of price is positively skewed

# %%
sns.boxplot(data = df1, x = 'body_style', y = 'price')
plt.show()

# %%
sns.boxplot(data = df1, x = 'bore')
plt.show()

# %%
df2 = pd.read_csv('/Users/siddhantraj/Desktop/Python/Python Udemy/Python-ML and Data Science/UNZIP_FOR_NOTEBOOKS_FINAL/05-Seaborn/StudentsPerformance.csv')

# %%
df2.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
plt.figure(figsize = (12,6))
sns.boxplot(x = 'parental level of education', y = 'math score', data = df2)
plt.show()

# %% [markdown]
# - Using the parameters like hue, orientation, width

# %%
plt.figure(figsize = (12,6))
sns.boxplot(x = 'parental level of education', y = 'math score', data = df2, hue = 'gender')
plt.show()

# %%
sns.boxplot(x = 'math score', y = 'parental level of education', data = df2, orient = 'h')
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.boxplot(x = 'parental level of education', y = 'math score', data =df2 ,width = 0.3)
plt.show()

# %% [markdown]
# ## Violin Plot
# - A violin plot allows us to visualise the distribution of a numeric variable for several groups just like box plot
# - it is similar to boxplot with a rotated plot on each side, giving more information about the density estimate on the y-axis
# - it displays the probability density across the data using KDE

# %%
sns.violinplot(data = df1, x = 'horsepower')
plt.show()

# %% [markdown]
# - The white dot in the plot represents the median
# - the thick gray bar in the center represents the interquartile range
# - the wider section of the plot represents a higher probability and the skinner sections represent a lower probability for the given value

# %%
sns.violinplot(data = df1, x = 'fuel_type', y = 'horsepower', orient = 'v')
plt.show()

# %%
sns.violinplot(data = df1, x = 'engine_size', y = 'fuel_type', )
plt.show()

# %%
sns.violinplot(data = df1, x = 'body_style', y = 'engine_size', palette = 'bright')
plt.show()

# %%
sns.violinplot(data = df1, x = 'engine_location', y = 'price', palette = 'colorblind')
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.violinplot(x = 'parental level of education', y = 'math score', data = df2)
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.violinplot(x = 'parental level of education', y = 'math score', data = df2, hue = 'gender')
plt.show()

# %% [markdown]
# - using the parameters like split, inner, orientation, bandwidth

# %%
plt.figure(figsize = (12,6))
sns.violinplot(x = 'parental level of education', y = 'math score', data = df2,
              hue = 'gender', split = True)
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.violinplot(x = 'parental level of education', y = 'math score', data = df2, inner = None)
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.violinplot(x = 'parental level of education', y = 'math score', data = df2, inner = 'point')
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.violinplot(x = 'parental level of education', y = 'math score', data = df2, inner = 'stick')
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.violinplot(x = 'parental level of education', y = 'math score', data = df2, inner = 'quartile')
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.violinplot(x = 'math score', y = 'parental level of education', data = df2)
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.violinplot(data = df2, x = 'parental level of education', y = 'math score', bw = 0.1)
plt.show()

# %% [markdown]
# ## Swarm Plot
# - a swarmplot simply shows all the data points in the distribution
# - for a very large data sets, it wont show all the points but will display the general distribution of them
# - it avoids overlapping of points

# %%
sns.swarmplot(data = df1, x = 'number_of_doors', y = 'price', )
plt.show()

# %% [markdown]
# - in a swarmplot dots are arranged in vertical columns
# - we can estimate the distribution of our data by looking at the width of the plot

# %%
sns.swarmplot(data = df1, x = 'fuel_type', y = 'price', hue = 'number_of_doors')
plt.show()

# %% [markdown]
# - Using the Parameters dodge, size

# %%
sns.swarmplot(data=df1, x = 'fuel_type', y = 'price', hue = 'number_of_doors', dodge = True)
plt.show()

# %%
sns.swarmplot(data = df2, x = 'math score')
plt.show()
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 15.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(data = df2, x = 'math score', size = 2)
plt.show()

# %%
sns.swarmplot(data = df2, x = 'math score', y = 'race/ethnicity', size = 2)
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.swarmplot(data = df2, x = 'race/ethnicity', y = 'math score', hue = 'gender', dodge = True,size =5)
plt.show()
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Bar Graph
